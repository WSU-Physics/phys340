# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %% [markdown]
# # Heading
# ## 2nd level heading
#
# write a lot of fun stuff. Make thing **bold** or *italic*.
#
# - item 1
# - item 2
#
# I can write equations inline like this: $E=mc^2$
#
# Or I can make a dedicated equation line:
#
# $$E=h\nu\;\;\;\;(1)$$

# %%
xdata = np.random.randn(100)
ydata = np.random.randn(100)

# %%
np.average(xdata)
# Out:
# 0.05272618042769564

# %%
np.average(ydata)
# Out:
# 0.035410363153309594

# %%
np.std(xdata)
# Out:
# 1.006411924454756

# %%
np.std(ydata)
# Out:
# 0.9104443376564636

# %%
plt.figure()
plt.plot(xdata, ydata, 'o')
plt.xlabel('xdata [units]')
plt.ylabel('Energy [Joules]')
plt.title('My plot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'My plot')

# %%
# # example data
# mu = 100  # mean of distribution
# sigma = 15  # standard deviation of distribution
# x = mu + sigma * np.random.randn(437)

num_bins = 20

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(xdata, num_bins, density=True)

ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tdata = np.arange(0, 10, 0.1)
vel = 1.5  # m/s
distance = vel * tdata + 0.1 * np.random.randn(len(tdata))

# %%
plt.figure()
#plt.plot(tdata, distance, 'o')
plt.errorbar(tdata, distance, yerr=0.1, xerr=0.01, ls='none')
plt.xlabel('time [s]')
plt.ylabel('distance [m]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'distance [m]')

# %% [markdown]
# # Reading from a file

# %%
# columns are: price, size, year, view
data = np.loadtxt("real_estate_price_size_year_view.csv", skiprows=1,
                  delimiter=',', usecols=(0, 1, 2))
view = np.loadtxt("real_estate_price_size_year_view.csv", skiprows=1,
                  delimiter=',', usecols=(3), dtype=str)

# %%
np.max(data[:, 0])
# Out:
# 500681.128

# %% [markdown]
# The most expensive house is $500,681.128

# %%
np.where(data[:, 0] == np.min(data[:, 0]))
# Out:
# (array([86]),)

# %%
print(np.min(data[:, 0]))
print(data[86, 2])
# Out:
# 154282.128
# 2006.0

# %% [markdown]
# # Before you go...
# - Double check all the TODOs on the lab handout
# - Upload your jupyter notebook to OSF
# - Reading quiz due tomorrow before class
# - We will start labs next week Tuesday
